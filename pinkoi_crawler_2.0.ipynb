# %%
import cmd
import requests
import re
import json
import csv
from bs4 import BeautifulSoup
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, wait, ProcessPoolExecutor

DOMAIN = "https://www.pinkoi.com"
STYLE_LIST = ['cute','minimal','romantic','neutral','vintage','zakka','urban','zen','green']

# %%
def crawl_comments(product_info):
    product_url = DOMAIN + product_info["url"]
    html_text = requests.get(product_url).text
    soup = BeautifulSoup(html_text,"html5lib")

    tid = re.findall('/product/(.{8})',html_text)[0]

    sssid = (soup.select_one("span.store-link-wrap > a")).attrs["href"]
    ssid = re.findall('/store/(.*)',sssid)
    sid = ssid[0]

    comments_url = "https://www.pinkoi.com/apiv2/review/get?tid=%s&makeup_by_sid=%s&limit=20"%(tid,sid)

    comments_text = requests.get(comments_url).text

    js = json.loads(comments_text)

    comments_list = []
    for comment in js['result']:
        comment_dict = {}
        comment_dict['id'] = comment['owner_nick']
        comment_dict['comment'] = comment['description']
        comment_dict['score'] = comment['score']
        comments_list.append(comment_dict)
    return comments_list

# %%
def crawl_list(category_url,style,page):    
    product_list = []
    html_text = requests.get('%s&style=%s&page=%s'%(category_url,style,page)).text
    soup = BeautifulSoup(html_text,'html5lib')
    urls = re.findall('div class="title"><a href="(/product/.*)?\?category',html_text)
    if (re.findall('class="m-filter-empty-result-wrapper"',html_text)):
        pass
    else:
        for url in urls:
            product_list.append({"url":url,"style":style})
        for product_info in product_list:
            crawl_product(product_info)

# %%
def crawl_product(product_info):

    product_url = DOMAIN + product_info["url"]

    html_text = requests.get(product_url).text

    product_dict = {}
    soup = BeautifulSoup(html_text,"html5lib")

    product_dict['style'] = product_info["style"]
    product_dict['title'] = soup.find('span',{"data-translate":"title"}).text
    product_dict['price'] = soup.select_one('span.amount').text
    product_dict['brand'] = soup.select_one('span.store-link-wrap > a').text
    if re.findall(r'<a href="/browse\?category=\d+&subcategory=\d+">(.*?)</a>',html_text):
        product_dict['category'] = re.findall(r'<a href="/browse\?category=\d+&subcategory=\d+">(.*?)</a>',html_text)[0]
    else:
        product_dict['category'] = "no info"
    if re.findall(r'<a href="/browse\?category=\d+&subcategory=\d+&material=\d+">(.*?)</a>',html_text):
        product_dict['material'] = re.findall(r'<a href="/browse\?category=\d+&subcategory=\d+&material=\d+">(.*?)</a>',html_text)[0]
    else:
        product_dict['material'] = "no info"
    product_dict['description'] = soup.select_one('div.m-richtext').text
    if re.findall(r'被欣賞 (\d+)',soup.select_one('div.box > ul > li').text.replace(',','')):
        product_dict['view_count'] = re.findall(r'被欣賞 (\d+)',soup.select_one('div.box > ul > li').text.replace(',',''))[0]
    else:
        product_dict['view_count'] = "0"
    product_dict['comments'] = crawl_comments(product_info)

    writer.writerow(product_dict)
    f.flush()
    
    print("crawled "+product_url)

# %%
##main methon
start_time = datetime.now()
category_url = 'https://www.pinkoi.com/browse/?category=9&subcategory=904'
category_num = re.findall('\?category=(\d+)',category_url)
subcategory_num = re.findall('subcategory=(\d+)',category_url)

##get the pages of all the style in this category
url_style_count = "https://www.pinkoi.com/apiv2/match?category=9&subcategory=904"
style_html_text = requests.get(url_style_count).text
js = json.loads(style_html_text)
style_terms = js["result"][0]["facets"]["style"]["terms"]
style_count = {'cute':0,'minimal':0,'romantic':0,'neutral':0,'vintage':0,'zakka':0,'urban':0,'zen':0,'green':0}
for style in style_terms:
    pages = 0
    if ((style["count"])%60 != 0):
        pages = ((style["count"])//60) + 1
    else:
        pages = ((style["count"])//60)        
    style_count[style["term"]] = pages
style_count

with open('pinkoi_%s_%s.csv'%(category_num[0],subcategory_num[0]),'w') as f:
    headers = ['title', 'price', 'category', 'material','brand','description','view_count','comments','style']
    writer = csv.DictWriter(f, fieldnames=headers)
    writer.writeheader()
    pool = ProcessPoolExecutor()
    futures = []
    for style in STYLE_LIST:
        for page in range(1,(style_count["%s"% style]+1)):
            future = pool.submit(crawl_list,category_url,style,page)
            futures.append(future)
            wait(futures)  
end_time = datetime.now()
time_spent = str(end_time - start_time).split(".")[0]
print('spent %s'%time_spent)
# Out:
# crawled https://www.pinkoi.com/product/7rs4WBtj
# crawled https://www.pinkoi.com/product/XVNXtM4U
# crawled https://www.pinkoi.com/product/RG4vg5qH
# crawled https://www.pinkoi.com/product/4gwU5KNp
# crawled https://www.pinkoi.com/product/98XuXb88
# crawled https://www.pinkoi.com/product/RYrrDbUx
# crawled https://www.pinkoi.com/product/dbibbtUx
# crawled https://www.pinkoi.com/product/kSZfzrXt
# crawled https://www.pinkoi.com/product/xVgfDSLY
# crawled https://www.pinkoi.com/product/DrDH7dvL
# crawled https://www.pinkoi.com/product/LqGKDpEY
# crawled https://www.pinkoi.com/product/ymeS4XkC
# crawled https://www.pinkoi.com/product/aDsXr94p
# crawled https://www.pinkoi.com/product/5JJuH7eQ
# crawled https://www.pinkoi.com/product/QAnNCkVq
# crawled https://www.pinkoi.com/product/19wUFcXj
# crawled https://www.pinkoi.com/product/1xwIS9kI
# crawled https://www.pinkoi.com/product/QDUxtEN3
# crawled https://www.pinkoi.com/product/897tMmCv
# crawled https://www.pinkoi.com/product/RswrAWJ8
# crawled https://www.pinkoi.com/product/CPywV2gr
# crawled https://www.pinkoi.com/product/7UY2yiBv
# crawled https://www.pinkoi.com/product/suP6KdSU
# crawled https://www.pinkoi.com/product/Py8NJSYA
# crawled https://www.pinkoi.com/product/5zdg2upC
# crawled https://www.pinkoi.com/product/PWtg3GJd
# crawled https://www.pinkoi.com/product/NJLhT852
# crawled https://www.pinkoi.com/product/JkBrwodE
# crawled https://www.pinkoi.com/product/dA3kwDgj
# crawled https://www.pinkoi.com/product/4Su5JeDh
# crawled https://www.pinkoi.com/product/5yT5dGzT
# crawled https://www.pinkoi.com/product/6rvh7v3E
# crawled https://www.pinkoi.com/product/Z32QNKu2
# crawled https://www.pinkoi.com/product/PmbyQB43
# crawled https://www.pinkoi.com/product/hSEzpFOE
# crawled https://www.pinkoi.com/product/xN7M6aUj
# crawled https://www.pinkoi.com/product/nkKeCR4o
# crawled https://www.pinkoi.com/product/1v5JoG8f
# crawled https://www.pinkoi.com/product/MEH38uSc
# crawled https://www.pinkoi.com/product/xNX8RvTb
# crawled https://www.pinkoi.com/product/0p0i15O0
# crawled https://www.pinkoi.com/product/Gz7TWCH7
# crawled https://www.pinkoi.com/product/kvcVPUUd
# crawled https://www.pinkoi.com/product/TE2ZShxG
# crawled https://www.pinkoi.com/product/SyWeydNd
# crawled https://www.pinkoi.com/product/ZovOC2yx
# crawled https://www.pinkoi.com/product/1OTX9ax6
# crawled https://www.pinkoi.com/product/H9ZR3cpG
# crawled https://www.pinkoi.com/product/7bc7CYYX
# crawled https://www.pinkoi.com/product/xVniVdiA
# crawled https://www.pinkoi.com/product/9Wh9ryTk
# crawled https://www.pinkoi.com/product/VF26kd26
# crawled https://www.pinkoi.com/product/gDqFJNtm
# crawled https://www.pinkoi.com/product/mxa2GjEK
# crawled https://www.pinkoi.com/product/fehdP3vH
# crawled https://www.pinkoi.com/product/1tsOcAFt
# crawled https://www.pinkoi.com/product/oggCHQXn
# crawled https://www.pinkoi.com/product/M6am7KgH
# crawled https://www.pinkoi.com/product/E9YqrrVv
# crawled https://www.pinkoi.com/product/xanXimf3
# crawled https://www.pinkoi.com/product/wPLnMp5M
# crawled https://www.pinkoi.com/product/jX7V473c
# crawled https://www.pinkoi.com/product/5sC8jpFW
# crawled https://www.pinkoi.com/product/wkzW5Eeg
# crawled https://www.pinkoi.com/product/1m85p8AN
# crawled https://www.pinkoi.com/product/1V8MkGeL
# crawled https://www.pinkoi.com/product/1lmYDteT
# crawled https://www.pinkoi.com/product/12oPYlMI
# crawled https://www.pinkoi.com/product/1XW9hOft
# crawled https://www.pinkoi.com/product/1MhG4O0s
# crawled https://www.pinkoi.com/product/7aQ9x5pU
# crawled https://www.pinkoi.com/product/93QRfcth
# crawled https://www.pinkoi.com/product/QcdiNVmF
# crawled https://www.pinkoi.com/product/hSq7iTs8
# crawled https://www.pinkoi.com/product/vXpCmaTW
# crawled https://www.pinkoi.com/product/wSZ3FFV9
# crawled https://www.pinkoi.com/product/HYsJJ3QC
# crawled https://www.pinkoi.com/product/rq1q7S7C
# crawled https://www.pinkoi.com/product/m6GKQRL9
# crawled https://www.pinkoi.com/product/7iQPFSbc
# crawled https://www.pinkoi.com/product/Dy2wQMgU
# crawled https://www.pinkoi.com/product/83mS39xY
# crawled https://www.pinkoi.com/product/PvuwfEb5
# crawled https://www.pinkoi.com/product/CM4zfJU4
# crawled https://www.pinkoi.com/product/Ck8RCyPt
# crawled https://www.pinkoi.com/product/3nrewM6z
# crawled https://www.pinkoi.com/product/9xLFnxTS
# crawled https://www.pinkoi.com/product/aNPczqsn
# crawled https://www.pinkoi.com/product/zbmR9n2F
# crawled https://www.pinkoi.com/product/4FMSk56m
# crawled https://www.pinkoi.com/product/B6shzamN
# crawled https://www.pinkoi.com/product/p2f7YRcw
# crawled https://www.pinkoi.com/product/Y79mrTY3
# crawled https://www.pinkoi.com/product/rrW9YfeA
# crawled https://www.pinkoi.com/product/1O35Q5i9
# crawled https://www.pinkoi.com/product/tDh5BtUs
# crawled https://www.pinkoi.com/product/Fw2Gp6p5
# crawled https://www.pinkoi.com/product/qjPLpi2Y
# crawled https://www.pinkoi.com/product/BUawtfFP
# crawled https://www.pinkoi.com/product/9XuixMg7
# crawled https://www.pinkoi.com/product/mHKXVTiu
# crawled https://www.pinkoi.com/product/FBYxcsqQ
# crawled https://www.pinkoi.com/product/m8qYViCP
# crawled https://www.pinkoi.com/product/zZ3kCKsS
# crawled https://www.pinkoi.com/product/Ejsakm7Q
# crawled https://www.pinkoi.com/product/my8TdJdE
# crawled https://www.pinkoi.com/product/ricXJ4rg
# crawled https://www.pinkoi.com/product/1ch7UlU2
# crawled https://www.pinkoi.com/product/15ib9F6i
# crawled https://www.pinkoi.com/product/1QN2XTuQ
# crawled https://www.pinkoi.com/product/xFxf5tGE
# crawled https://www.pinkoi.com/product/ur6Z4Mth
# crawled https://www.pinkoi.com/product/16FPTuDm
# crawled https://www.pinkoi.com/product/1ZsyyStI
# crawled https://www.pinkoi.com/product/1UACr4kx
# crawled https://www.pinkoi.com/product/iVhDsiTr
# crawled https://www.pinkoi.com/product/1sOzaHH6
# crawled https://www.pinkoi.com/product/1BWMk0pI
# crawled https://www.pinkoi.com/product/ik2w9kSw
# crawled https://www.pinkoi.com/product/cmGhFAnG
# crawled https://www.pinkoi.com/product/1FAOSzM6
# crawled https://www.pinkoi.com/product/18IeH0w1
# crawled https://www.pinkoi.com/product/1f9hVKqq
# crawled https://www.pinkoi.com/product/1U0aZnUU
# crawled https://www.pinkoi.com/product/kNtdSEZX
# crawled https://www.pinkoi.com/product/z3EpXtiG
# crawled https://www.pinkoi.com/product/vnmcnv2q
# crawled https://www.pinkoi.com/product/1IF12Z5U
# crawled https://www.pinkoi.com/product/1CzyyMSR
# crawled https://www.pinkoi.com/product/1CVt9Fqv
# crawled https://www.pinkoi.com/product/7FPx9nJ5
# crawled https://www.pinkoi.com/product/14pReV8w
# crawled https://www.pinkoi.com/product/VahAypyA
# crawled https://www.pinkoi.com/product/Bk6TwMyR
# spent 0:04:22

# %%
a =1
a!=2
# Out:
# True
